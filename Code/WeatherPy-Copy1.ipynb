# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"
weather_stas_df = output_data_file

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ### START OF API CALL. DON'T RUN AGAIN.

# %%
# Keeping count of number of cities
count = 0
set_num = 0
error = 0

#get current time
t0 = time.time()

# set up lists to hold response info
city_name = []
country = []
max_temp = []
min_temp = []
feels_like = []
date = []
lat = []
lon = []
humidity = []
cloudiness = []
wind_speed = []

# print the header for the data loop
print('Beginning Data Retrieval')
print('--------------------------------')

# loop through cities and and perform a request for data on each
for city in cities:
    
    response = requests.get(query_url + city).json()
    
    try:
        print(f"Processing Record {count} of Set {set_num} | {city_name}.")
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        max_temp.append(response["main"]["temp_max"])
        min_temp.append(response["main"]["temp_min"])
        feels_like.append(response["main"]["feels_like"])
        date.append(response["dt"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        
    except Exception as not_found:
        print("City not found. Skipping...")
        continue

    # loop a few cities per minute to avoid getting API suspended    
    if count == 45:
        t1 = time.time()
        count = 1
        set_num +=1
        time.sleep(60-(t1-t0))
        t0 = time.time()
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 0 of Set 0 | [].
# Processing Record 0 of Set 0 | ['Upernavik'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus'].
# City not found. Skipping...
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus'].
# City not found. Skipping...
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff', 'Rabo de Peixe'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff', 'Rabo de Peixe', 'Laguna'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff', 'Rabo de Peixe', 'Laguna', 'Ushuaia'].
# City not found. Skipping...
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaru
].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff', 'Rabo de Peixe', 'Laguna', 'Ushuaia', 'Umba', "Severo-Kuril'sk", 'Carnarvon', 'Mossamedes', 'Qaqortoq', 'Sawtell', 'Colomi', 'Huarmey', 'Jalu', 'Cidreira', 'Lorengau', "Ol'ga", 'Iqaluit', 'Cabo San Lucas', 'Omsukchan'].
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff', 'Rabo de Peixe', 'Laguna', 'Ushuaia', 'Umba', "Severo-Kuril'sk", 'Carnarvon', 'Mossamedes', 'Qaqortoq', 'Sawtell', 'Colomi', 'Huarmey', 'Jalu', 'Cidreira', 'Lorengau', "Ol'ga", 'Iqaluit', 'Cabo San Lucas', 'Omsukchan', 'Avarua'].
# ...
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff', 'Rabo de Peixe', 'Laguna', 'Ushuaia', 'Umba', "Severo-Kuril'sk", 'Carnarvon', 'Mossamedes', 'Qaqortoq', 'Sawtell', 'Colomi', 'Huarmey', 'Jalu', 'Cidreira', 'Lorengau', "Ol'ga", 'Iqaluit', 'Cabo San Lucas', 'Omsukchan', 'Avarua', 'Smithers', 'Deputatsky', 'Barrow', 'San Patricio', 'Port Hardy', 'Tiznit Province', 'Shelburne', 'Tabriz', 'Toulouse', 'Thompson', 'Pacifica', 'Bambous Virieux', 'Atambua', 'Sambava', 'Port Alfred', 'Los Llanos de Aridane', 'Clyde River', 'Dickinson', 'George Town', 'Jumla', 'Provideniya', 'Marsá Maţrūḩ', 'Port Hedland', 'Roald', 'Hong Kong', 'Yambio', 'Touros', 'Lagoa', 'Vaini', 'Pangnirtung', 'Camacha', 'Narsaq', 'Tasiilaq', 'Tiksi', 'Gobabis', 'Senanga', 'Nikolskoye', 'Saint George', 'Turukhansk', 'Ostrovnoy', 'Chui', 'Buala', 'Sumbe', 'Acapulco de Juárez', 'Ulaanbaatar', 'Kaitangata', 'Hobart', 'Gijang', 'East London', 'Tautira', 'Banda Aceh', 'Port-Gentil', 'Vigrestad', 'Alice Springs', 'Longyearbyen', 'Palafrugell', 'Bilibino', 'Resende', 'Castro', 'Tonantins', 'Chupaca', 'Ilulissat', 'Olafsvik', 'Kavieng', 'Merauke', 'Talnakh', 'San Andrés', 'Bocanda', 'São João da Barra', 'Grindavik', 'Cherskiy', 'Cape Town', 'Constitución', 'College', 'Pacific Grove', 'Podgorica', 'Zeya', 'Charters Towers', 'Zambezi', 'Suntar', 'Gorom-Gorom', 'Halifax', 'Pevek', 'Ancud', 'Faanui', 'Quatre Cocos', 'Hualmay', 'Payakumbuh', 'Jamestown', 'Ponta Delgada', 'Kahului', 'Safidon', 'Las Tunas', 'Payson', 'Ponta do Sol', 'Port Lincoln', 'Taltal', 'Kalmunai', 'Torbay', 'Jiamusi', 'Qinzhou', 'Gushikawa', 'Tagusao', 'Honiara', 'Ginda', 'Pisco', 'Port Elizabeth', 'Lata', 'Voh', 'Spirovo', 'Kovernino', 'Miramar', 'Ahipara', 'Saint-Augustin', 'Faya', 'Sisimiut', 'Kirakira', 'San Miguel', 'Vicuña', 'Chāndūr Bāzār', 'São Filipe', 'Aripuanã', 'Stephenville Crossing', 'Yurga', 'Ogdensburg', 'Yong’an', 'Mgandu', 'Kushmurun', 'Bud', 'Korla', 'Carutapera', 'Paciran', 'Teacapan', 'Dābhol', 'Mount Gambier', 'Flin Flon', 'Aykhal', 'Murakami', 'Esperance', 'Kumul', 'Dunedin', 'Isiro', 'Pingshan', 'Atyrau', 'Leningradskiy', 'Vao', 'Pontianak', 'Codrington', 'Miracema do Tocantins', 'Pyatovskiy', 'Tuatapere', 'Caravelas', 'Dallas', 'Meulaboh', 'San Rafael del Sur', 'Pinerolo', 'Poum', 'Rio Grande', 'Dargaville', 'Moroni', 'Tuktoyaktuk', 'Quang Ngai', 'Kisangani', 'Saint Paul Harbor', 'Airai', 'Benguela', 'Amazar', 'Mozarlândia', 'Broome', 'Gigmoto', 'Baruun-Urt', 'Okhotsk', 'Urengoy', 'Løding', 'Honningsvåg', 'Onega', 'North Bend', 'Gurupá', 'Sivaki', 'Oliva', 'Dongsheng', 'Mitú', 'Chokurdakh', 'Alakurtti', 'Manaquiri', 'Rudnogorsk', 'Russell', 'Santa Maria', 'Pyaozerskiy', 'Inta', 'Santa Cruz de Barahona', 'Hérouville-Saint-Clair', 'Broken Hill', 'Yulara', 'Orange', 'Romny', 'Coquimbo', 'Sørland', 'Mumford', 'Hambantota', 'Boende', 'Saint-Pierre', 'Riverton', 'Hadrut', 'Inuvik', 'Nové Město nad Metují', 'Kismayo', 'Ortaköy', 'Vanimo', 'Ban Nahin', 'Palu', 'Otukpo', 'Nome', 'Vigeland', 'Taoudenni', 'Valdez', 'Mehamn', 'Sinnamary', 'Mount Isa', 'Dolores', "Kargopol'", 'Ariquemes', 'Dospat', 'Ust-Kuyga', 'Kiama', 'Mujiayingzi', 'Yamada', 'Berezanka', 'Manokwari', 'Te Anau', 'Fort Nelson', 'Newtownards', 'Plérin', 'Oranjemund', 'Guerrero N ...
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff', 'Rabo de Peixe', 'Laguna', 'Ushuaia', 'Umba', "Severo-Kuril'sk", 'Carnarvon', 'Mossamedes', 'Qaqortoq', 'Sawtell', 'Colomi', 'Huarmey', 'Jalu', 'Cidreira', 'Lorengau', "Ol'ga", 'Iqaluit', 'Cabo San Lucas', 'Omsukchan', 'Avarua', 'Smithers', 'Deputatsky', 'Barrow', 'San Patricio', 'Port Hardy', 'Tiznit Province', 'Shelburne', 'Tabriz', 'Toulouse', 'Thompson', 'Pacifica', 'Bambous Virieux', 'Atambua', 'Sambava', 'Port Alfred', 'Los Llanos de Aridane', 'Clyde River', 'Dickinson', 'George Town', 'Jumla', 'Provideniya', 'Marsá Maţrūḩ', 'Port Hedland', 'Roald', 'Hong Kong', 'Yambio', 'Touros', 'Lagoa', 'Vaini', 'Pangnirtung', 'Camacha', 'Narsaq', 'Tasiilaq', 'Tiksi', 'Gobabis', 'Senanga', 'Nikolskoye', 'Saint George', 'Turukhansk', 'Ostrovnoy', 'Chui', 'Buala', 'Sumbe', 'Acapulco de Juárez', 'Ulaanbaatar', 'Kaitangata', 'Hobart', 'Gijang', 'East London', 'Tautira', 'Banda Aceh', 'Port-Gentil', 'Vigrestad', 'Alice Springs', 'Longyearbyen', 'Palafrugell', 'Bilibino', 'Resende', 'Castro', 'Tonantins', 'Chupaca', 'Ilulissat', 'Olafsvik', 'Kavieng', 'Merauke', 'Talnakh', 'San Andrés', 'Bocanda', 'São João da Barra', 'Grindavik', 'Cherskiy', 'Cape Town', 'Constitución', 'College', 'Pacific Grove', 'Podgorica', 'Zeya', 'Charters Towers', 'Zambezi', 'Suntar', 'Gorom-Gorom', 'Halifax', 'Pevek', 'Ancud', 'Faanui', 'Quatre Cocos', 'Hualmay', 'Payakumbuh', 'Jamestown', 'Ponta Delgada', 'Kahului', 'Safidon', 'Las Tunas', 'Payson', 'Ponta do Sol', 'Port Lincoln', 'Taltal', 'Kalmunai', 'Torbay', 'Jiamusi', 'Qinzhou', 'Gushikawa', 'Tagusao', 'Honiara', 'Ginda', 'Pisco', 'Port Elizabeth', 'Lata', 'Voh', 'Spirovo', 'Kovernino', 'Miramar', 'Ahipara', 'Saint-Augustin', 'Faya', 'Sisimiut', 'Kirakira', 'San Miguel', 'Vicuña', 'Chāndūr Bāzār', 'São Filipe', 'Aripuanã', 'Stephenville Crossing', 'Yurga', 'Ogdensburg', 'Yong’an', 'Mgandu', 'Kushmurun', 'Bud', 'Korla', 'Carutapera', 'Paciran', 'Teacapan', 'Dābhol', 'Mount Gambier', 'Flin Flon', 'Aykhal', 'Murakami', 'Esperance', 'Kumul', 'Dunedin', 'Isiro', 'Pingshan', 'Atyrau', 'Leningradskiy', 'Vao', 'Pontianak', 'Codrington', 'Miracema do Tocantins', 'Pyatovskiy', 'Tuatapere', 'Caravelas', 'Dallas', 'Meulaboh', 'San Rafael del Sur', 'Pinerolo', 'Poum', 'Rio Grande', 'Dargaville', 'Moroni', 'Tuktoyaktuk', 'Quang Ngai', 'Kisangani', 'Saint Paul Harbor', 'Airai', 'Benguela', 'Amazar', 'Mozarlândia', 'Broome', 'Gigmoto', 'Baruun-Urt', 'Okhotsk', 'Urengoy', 'Løding', 'Honningsvåg', 'Onega', 'North Bend', 'Gurupá', 'Sivaki', 'Oliva', 'Dongsheng', 'Mitú', 'Chokurdakh', 'Alakurtti', 'Manaquiri', 'Rudnogorsk', 'Russell', 'Santa Maria', 'Pyaozerskiy', 'Inta', 'Santa Cruz de Barahona', 'Hérouville-Saint-Clair', 'Broken Hill', 'Yulara', 'Orange', 'Romny', 'Coquimbo', 'Sørland', 'Mumford', 'Hambantota', 'Boende', 'Saint-Pierre', 'Riverton', 'Hadrut', 'Inuvik', 'Nové Město nad Metují', 'Kismayo', 'Ortaköy', 'Vanimo', 'Ban Nahin', 'Palu', 'Otukpo', 'Nome', 'Vigeland', 'Taoudenni', 'Valdez', 'Mehamn', 'Sinnamary', 'Mount Isa', 'Dolores', "Kargopol'", 'Ariquemes', 'Dospat', 'Ust-Kuyga', 'Kiama', 'Mujiayingzi', 'Yamada', 'Berezanka', 'Manokwari', 'Te Anau', 'Fort Nelson', 'Newtownards', 'Plérin', 'Oranjemund', 'Guerrero N ...
# Processing Record 0 of Set 0 | ['Upernavik', 'Norman Wells', 'Rāmgarh', 'Camocim', 'Umm Kaddadah', 'Saint-Joseph', 'Atuona', 'Høyanger', 'Margate', 'Kapaa', 'Klaksvík', 'Yellowknife', 'Punta Arenas', 'Qaanaaq', 'Maracaibo', 'Srednekolymsk', 'Mataura', 'Artvin Province', 'Hermanus', 'Saskylakh', 'Muros', 'Butaritari', 'Hithadhoo', 'Khani', 'Bethel', 'Benxi', 'Mahébourg', 'Bengkulu', 'Japura', 'Ardakān', 'Mar del Plata', 'Saint-Philippe', 'Belmonte', 'Port Macquarie', 'La Libertad', 'Khatanga', 'Tommot', 'Arraial do Cabo', 'Hasaki', 'Balkhash', 'Busselton', 'Puerto Ayora', 'Hilo', 'Goderich', 'Paamiut', 'Dikson', 'Karema', 'Rikitea', 'Bredasdorp', 'Port Augusta', 'Albany', 'Mabaruma', 'Katsuura', 'Ribeira Grande', 'Khilok', 'Bogorodskoye', 'Ulladulla', 'Mandurah', 'New Norfolk', 'Arroyos y Esteros', 'Bluff', 'Rabo de Peixe', 'Laguna', 'Ushuaia', 'Umba', "Severo-Kuril'sk", 'Carnarvon', 'Mossamedes', 'Qaqortoq', 'Sawtell', 'Colomi', 'Huarmey', 'Jalu', 'Cidreira', 'Lorengau', "Ol'ga", 'Iqaluit', 'Cabo San Lucas', 'Omsukchan', 'Avarua', 'Smithers', 'Deputatsky', 'Barrow', 'San Patricio', 'Port Hardy', 'Tiznit Province', 'Shelburne', 'Tabriz', 'Toulouse', 'Thompson', 'Pacifica', 'Bambous Virieux', 'Atambua', 'Sambava', 'Port Alfred', 'Los Llanos de Aridane', 'Clyde River', 'Dickinson', 'George Town', 'Jumla', 'Provideniya', 'Marsá Maţrūḩ', 'Port Hedland', 'Roald', 'Hong Kong', 'Yambio', 'Touros', 'Lagoa', 'Vaini', 'Pangnirtung', 'Camacha', 'Narsaq', 'Tasiilaq', 'Tiksi', 'Gobabis', 'Senanga', 'Nikolskoye', 'Saint George', 'Turukhansk', 'Ostrovnoy', 'Chui', 'Buala', 'Sumbe', 'Acapulco de Juárez', 'Ulaanbaatar', 'Kaitangata', 'Hobart', 'Gijang', 'East London', 'Tautira', 'Banda Aceh', 'Port-Gentil', 'Vigrestad', 'Alice Springs', 'Longyearbyen', 'Palafrugell', 'Bilibino', 'Resende', 'Castro', 'Tonantins', 'Chupaca', 'Ilulissat', 'Olafsvik', 'Kavieng', 'Merauke', 'Talnakh', 'San Andrés', 'Bocanda', 'São João da Barra', 'Grindavik', 'Cherskiy', 'Cape Town', 'Constitución', 'College', 'Pacific Grove', 'Podgorica', 'Zeya', 'Charters Towers', 'Zambezi', 'Suntar', 'Gorom-Gorom', 'Halifax', 'Pevek', 'Ancud', 'Faanui', 'Quatre Cocos', 'Hualmay', 'Payakumbuh', 'Jamestown', 'Ponta Delgada', 'Kahului', 'Safidon', 'Las Tunas', 'Payson', 'Ponta do Sol', 'Port Lincoln', 'Taltal', 'Kalmunai', 'Torbay', 'Jiamusi', 'Qinzhou', 'Gushikawa', 'Tagusao', 'Honiara', 'Ginda', 'Pisco', 'Port Elizabeth', 'Lata', 'Voh', 'Spirovo', 'Kovernino', 'Miramar', 'Ahipara', 'Saint-Augustin', 'Faya', 'Sisimiut', 'Kirakira', 'San Miguel', 'Vicuña', 'Chāndūr Bāzār', 'São Filipe', 'Aripuanã', 'Stephenville Crossing', 'Yurga', 'Ogdensburg', 'Yong’an', 'Mgandu', 'Kushmurun', 'Bud', 'Korla', 'Carutapera', 'Paciran', 'Teacapan', 'Dābhol', 'Mount Gambier', 'Flin Flon', 'Aykhal', 'Murakami', 'Esperance', 'Kumul', 'Dunedin', 'Isiro', 'Pingshan', 'Atyrau', 'Leningradskiy', 'Vao', 'Pontianak', 'Codrington', 'Miracema do Tocantins', 'Pyatovskiy', 'Tuatapere', 'Caravelas', 'Dallas', 'Meulaboh', 'San Rafael del Sur', 'Pinerolo', 'Poum', 'Rio Grande', 'Dargaville', 'Moroni', 'Tuktoyaktuk', 'Quang Ngai', 'Kisangani', 'Saint Paul Harbor', 'Airai', 'Benguela', 'Amazar', 'Mozarlândia', 'Broome', 'Gigmoto', 'Baruun-Urt', 'Okhotsk', 'Urengoy', 'Løding', 'Honningsvåg', 'Onega', 'North Bend', 'Gurupá', 'Sivaki', 'Oliva', 'Dongsheng', 'Mitú', 'Chokurdakh', 'Alakurtti', 'Manaquiri', 'Rudnogorsk', 'Russell', 'Santa Maria', 'Pyaozerskiy', 'Inta', 'Santa Cruz de Barahona', 'Hérouville-Saint-Clair', 'Broken Hill', 'Yulara', 'Orange', 'Romny', 'Coquimbo', 'Sørland', 'Mumford', 'Hambantota', 'Boende', 'Saint-Pierre', 'Riverton', 'Hadrut', 'Inuvik', 'Nové Město nad Metují', 'Kismayo', 'Ortaköy', 'Vanimo', 'Ban Nahin', 'Palu', 'Otukpo', 'Nome', 'Vigeland', 'Taoudenni', 'Valdez', 'Mehamn', 'Sinnamary', 'Mount Isa', 'Dolores', "Kargopol'", 'Ariquemes', 'Dospat', 'Ust-Kuyga', 'Kiama', 'Mujiayingzi', 'Yamada', 'Berezanka', 'Manokwari', 'Te Anau', 'Fort Nelson', 'Newtownards', 'Plérin', 'Oranjemund', 'Guerrero N ...

# %% [markdown]
# ### END OF API CALL. DON'T RUN AGAIN.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# saved df to csv
weather_data.to_csv("../output_data/weather_data.csv", index=False, header=True)

# %%
# put variables from API call into a df
weather_dict = {"City":city_name, "Cloudiness":cloudiness, 
                "Country":country, "Date":date, "Humidity":humidity,   
                "Lat":lat, "Lng":lon, "Max Temp":max_temp, "Min Temp": min_temp,
                "Feels Like":feels_like,"Wind Speed":wind_speed}

weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Upernavik           0      GL  1598655460        71  72.79  -56.15
# 1  Norman Wells          90      CA  1598655397        66  65.28 -126.83
# 2       Rāmgarh           7      IN  1598655037        87  23.63   85.52
# 3       Camocim          14      BR  1598655037        72  -2.90  -40.84
# 4  Umm Kaddadah          71      SD  1598655037        55  13.60   26.69
#
#    Max Temp  Min Temp  Feels Like  Wind Speed
# 0      4.64      4.64       -2.30        7.04
# 1     11.00     11.00        6.98        4.10
# 2     22.88     22.88       25.20        2.38
# 3     26.10     26.10       24.28        8.33
# 4     28.30     28.30       30.31        1.35

# %%
# # convert datetime to readable date
# print(weather_data['Date'].dtype)

# weather_data['Date'] = pd.to_datetime(weather_data['Date'])
# print(weather_data['Date'].dtype)

# weather_data['Year'] = weather_data['Date'].dt.year
# weather_data['Month'] = weather_data['Date'].dt.month
# weather_data['Day'] = weather_data['Date'].dt.day
# Out:
# datetime64[ns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a Scatter Plot for latitude & max temp. Save as png.
x_values = weather_data['Lat']
y_values = weather_data['Max Temp']

plt.scatter(x_values,y_values,edgecolor="black", 
            linewidths=1, marker="o", alpha=0.8)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(F)')
plt.savefig('Lat_MaxTemp.png')
plt.grid(True)
plt.xlim([-60, 100])
plt.ylim([-20, 60])
plt.show()

# State findings
print("""Analysis: Based off of the graph above, it looks like there's a strong non-linear relationship 
   between max tempurature(F) and latitude. There's also a noticible gap where the latitude 
   is about 50 and max temperature is around 80 degrees.
    """)
# Out:
# Analysis: Based off of the graph above, it looks like there's a strong non-linear relationship
#    between max tempurature(F) and latitude. There's also a noticible gap where the latitude
#    is about 50 and max temperature is around 80 degrees.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a Scatter Plot for latitude & humidity
x_values = weather_data['Lat']
y_values = weather_data['Humidity']

plt.scatter(x_values,y_values,edgecolor="black", 
            linewidths=1, marker="o", alpha=0.8)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig('Lat_Humidity.png')
plt.grid(True)
plt.xlim([-60, 100])
plt.ylim([0, 120])
plt.show()

# State findings
print("Analysis: Based off of the graph above, it shows that humidity isn't affected by latitude.")
# Out:
# Analysis: Based off of the graph above, it shows that humidity (except for one outlier) isn't affected by latitude.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create a Scatter Plot for latitude & cloudiness
x_values = weather_data['Lat']
y_values = weather_data['Cloudiness']

plt.scatter(x_values,y_values,edgecolor="black", 
            linewidths=1, marker="o", alpha=0.8)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('Lat_Cloudiness.png')
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([-20, 120])
plt.show()

# State findings
print("Analysis: Based off of the graph above, there's no relationship between cloudiness and latitude.")
# Out:
# Analysis: Based off of the graph above, there's no relationship between cloudiness and latitude.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a Scatter Plot for latitude & wind speed
x_values = weather_data['Lat']
y_values = weather_data['Wind Speed']

plt.scatter(x_values,y_values,edgecolor="black", 
            linewidths=1, marker="o", alpha=0.8)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.savefig('Lat_WindSpeed.png')
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([-2, 17.5])
plt.show()

# State findings
print("Analysis: Based off of the graph above, the wind speed (except for a few outliers) is not related to latitude.")
# Out:
# Analysis: Based off of the graph above, the wind speed (except for a few outliers) is not related to latitude.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
#the cities needs to be split between the two somehow...
northern_hemi = pd.DataFrame(>=0)
southern_hemi = pd.DataFrame(<=0)
# Out:
#   File "<ipython-input-29-4856e347dab8>", line 3
#     northern_hemi = pd.DataFrame(>=0)
#                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Make x & y values for max tem & latitude
x_values = weather_data['Lat']
y_values = weather_data['Max Temp']    

# Perform a linear regression on max temperature vs. latitude & get regression values
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create a line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot
plt.scatter(x_values,y_values,edgecolor="black", 
            linewidths=1, marker="o", alpha=0.8)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(F)')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Your second requirement is to run linear regression on each relationship, 
#only this time separating them into Northern Hemisphere 
#(greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude)

#Northern Hemisphere - Humidity (%) vs. Latitude
x_values = weather_data['Lat']
y_values = weather_data['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolor="black", 
            linewidths=1, marker="o", alpha=0.8)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude
x_values = weather_stats_df['Lat']
y_values = weather_stats_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolor="black", 
            linewidths=1, marker="o", alpha=0.8)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Southern Hemisphere - Cloudiness (%) vs. Latitude

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
x_values = weather_stats_df['Lat']
y_values = weather_stats_df['Wind Speed(mph)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,edgecolor="black", 
            linewidths=1, marker="o", alpha=0.8)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Southern Hemisphere - Wind Speed (mph) vs. Latitude
